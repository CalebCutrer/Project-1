# %%
# Dependencies
import pandas as pd # type: ignore
from pathlib import Path
import pyreadstat  # type: ignore

# %% [markdown]
# ## Importing Merged Dataset - Columns of Interest

# %%
# (By the row in the read_csv function code): prescription meds, then demographics, then physical activity, then sleep disorders 
Distilled_Data = pd.read_csv("Datasets/Merged_Dataset", usecols=['SEQN',
                                                                 'RXDUSE', 'RXDDAYS', 'RXDCOUNT',
                                                                 'RIAGENDR', 'RIDAGEYR', 'RIDRETH3', 'DMDEDUC2', 'DMDMARTZ', 'WTINTPRP', 'WTMECPRP', 'INDFMPIR',
                                                                 'PAQ605', 'PAQ610', 'PAD615', 'PAQ620', 'PAQ625', 'PAD630', 'PAQ635', 'PAQ640', 'PAD645', 'PAQ650', 'PAQ655', 'PAD660', 'PAQ665', 'PAQ670', 'PAD675', 'PAD680',
                                                                 'SLQ300', 'SLQ310', 'SLD012', 'SLQ320', 'SLQ330', 'SLD013','SLQ030', 'SLQ040', 'SLQ050', 'SLQ120'
                                                                 ])

Distilled_Data.head()
# Out:
#        SEQN  RXDUSE  RXDDAYS  RXDCOUNT  RIAGENDR  RIDAGEYR  RIDRETH3  \
# 0  109263.0     2.0      NaN       NaN       1.0       2.0       6.0
# 1  109264.0     2.0      NaN       NaN       2.0      13.0       1.0
# 2  109265.0     2.0      NaN       NaN       1.0       2.0       3.0
# 3  109266.0     2.0      NaN       NaN       2.0      29.0       6.0
# 4  109267.0     1.0      NaN       1.0       2.0      21.0       2.0
#
#    DMDEDUC2  DMDMARTZ      WTINTPRP  ...    SLQ300    SLQ310  SLD012  \
# 0       NaN       NaN   7891.762435  ...       NaN       NaN     NaN
# 1       NaN       NaN  11689.747264  ...       NaN       NaN     NaN
# 2       NaN       NaN  16273.825939  ...       NaN       NaN     NaN
# 3       5.0       3.0   7825.646112  ...  b'22:00'  b'05:30'     7.5
# 4       4.0       3.0  26379.991724  ...  b'00:00'  b'08:00'     8.0
#
#      SLQ320    SLQ330  SLD013        SLQ030        SLQ040  SLQ050  \
# 0       NaN       NaN     NaN           NaN           NaN     NaN
# 1       NaN       NaN     NaN           NaN           NaN     NaN
# 2       NaN       NaN     NaN           NaN           NaN     NaN
# 3  b'23:00'  b'07:00'     8.0  1.000000e+00  5.397605e-79     2.0
# 4  b'03:00'  b'11:00'     8.0  5.397605e-79  5.397605e-79     2.0
#
#          SLQ120
# 0           NaN
# 1           NaN
# 2           NaN
# 3  5.397605e-79
# 4  2.000000e+00
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Renaming Variables

# %%
Distilled_Data_Renamed = Distilled_Data.rename(columns= {'SEQN': "Respondent ID", 
                                                         'RXDUSE': "Taken Rx Past Month" , 
                                                         'RXDDAYS': "Number Days Taken Rx", 
                                                         'RXDCOUNT': "Number of Rx Meds", 
                                                         'RIAGENDR': "Gender", 
                                                         'RIDAGEYR': "Age at Screening", 
                                                         'RIDRETH3': "Race", 
                                                         'DMDEDUC2': "Educational Attainment", 
                                                         'DMDMARTZ': "Marital Status", 
                                                         'WTINTPRP': "Sample Interview Weight", 
                                                         'WTMECPRP': "MEC Sample Weight",
                                                         'INDFMPIR': "Family Income to Poverty Ratio", 
                                                         'PAQ605': "Vigorous Work Activity", 
                                                         'PAQ610': "Number of Days Vigorous Work", 
                                                         'PAD615': "Minutes of Vigorous Work Daily", 
                                                         'PAQ620': "Moderate Work Activity",
                                                         'PAQ625': "Number of Days Moderate Work", 
                                                         'PAD630': "Minutes of Moderate Work Daily", 
                                                         'PAQ635': "Walk or Bike Travel", 
                                                         'PAQ640': "Number of Days Walk or Bike Weekly", 
                                                         'PAD645': "Daily Minutes Walking or Biking", 
                                                         'PAQ650': "Vigorous Recreational Activity", 
                                                         'PAQ655': "Number of Days Vigorous Recreation", 
                                                         'PAD660': "Minutes of Vigorous Recreation Daily", 
                                                         'PAQ665': "Moderate Recreational Activity", 
                                                         'PAQ670': "Number of Days Moderate Recreation", 
                                                         'PAD675': "Minutes of Moderate Recreation Daily", 
                                                         'PAD680': "Minutes of Sedentary Activity Daily",
                                                         'SLQ300': "Bedtime Week/Workdays",
                                                         'SLQ310': "Waketime Week/Workdays", 
                                                         'SLD012': "Sleep Hours Week/Workdays", 
                                                         'SLQ320': "Bedtime Weekends", 
                                                         'SLQ330': "Waketime Weekends", 
                                                         'SLD013': "Sleep Hours Weekends",
                                                         'SLQ030': "Snoring Frequency Past Year", 
                                                         'SLQ040': "Frequency Snort/Stop Breathing Past Year", 
                                                         'SLQ050': "Told Doctor About Sleep Issues", 
                                                         'SLQ120': "Feeling Tired During Day Frequency"

})

Distilled_Data_Renamed.head()
# Out:
#    Respondent ID  Taken Rx Past Month  Number Days Taken Rx  \
# 0       109263.0                  2.0                   NaN
# 1       109264.0                  2.0                   NaN
# 2       109265.0                  2.0                   NaN
# 3       109266.0                  2.0                   NaN
# 4       109267.0                  1.0                   NaN
#
#    Number of Rx Meds  Gender  Age at Screening  Race  Educational Attainment  \
# 0                NaN     1.0               2.0   6.0                     NaN
# 1                NaN     2.0              13.0   1.0                     NaN
# 2                NaN     1.0               2.0   3.0                     NaN
# 3                NaN     2.0              29.0   6.0                     5.0
# 4                1.0     2.0              21.0   2.0                     4.0
#
#    Marital Status  Sample Interview Weight  ...  Bedtime Week/Workdays  \
# 0             NaN              7891.762435  ...                    NaN
# 1             NaN             11689.747264  ...                    NaN
# 2             NaN             16273.825939  ...                    NaN
# 3             3.0              7825.646112  ...               b'22:00'
# 4             3.0             26379.991724  ...               b'00:00'
#
#    Waketime Week/Workdays  Sleep Hours Week/Workdays  Bedtime Weekends  \
# 0                     NaN                        NaN               NaN
# 1                     NaN                        NaN               NaN
# 2                     NaN                        NaN               NaN
# 3                b'05:30'                        7.5          b'23:00'
# 4                b'08:00'                        8.0          b'03:00'
#
#    Waketime Weekends  Sleep Hours Weekends  Snoring Frequency Past Year  \
# 0                NaN                   NaN                          NaN
# 1                NaN                   NaN                          NaN
# 2                NaN                   NaN                          NaN
# 3           b'07:00'                   8.0                 1.000000e+00
# 4           b'11:00'                   8.0                 5.397605e-79
#
#    Frequency Snort/Stop Breathing Past Year  Told Doctor About Sleep Issues  \
# 0                                       NaN                             NaN
# 1                                       NaN                             NaN
# 2                                       NaN                             NaN
# 3                              5.397605e-79                             2.0
# 4                              5.397605e-79                             2.0
#
#    Feeling Tired During Day Frequency
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                        5.397605e-79
# 4                        2.000000e+00
#
# [5 rows x 38 columns]

# %%
# Overview of df and variables:
Distilled_Data_Renamed.describe()
Distilled_Data_Renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32962 entries, 0 to 32961
# Data columns (total 38 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Respondent ID                             32962 non-null  float64
#  1   Taken Rx Past Month                       32962 non-null  float64
#  2   Number Days Taken Rx                      24031 non-null  float64
#  3   Number of Rx Meds                         24246 non-null  float64
#  4   Gender                                    32962 non-null  float64
#  5   Age at Screening                          32962 non-null  float64
#  6   Race                                      32962 non-null  float64
#  7   Educational Attainment                    25746 non-null  float64
#  8   Marital Status                            25746 non-null  float64
#  9   Sample Interview Weight                   32962 non-null  float64
#  10  MEC Sample Weight                         32962 non-null  float64
#  11  Family Income to Poverty Ratio            28411 non-null  float64
#  12  Vigorous Work Activity                    26301 non-null  float64
#  13  Number of Days Vigorous Work              5466 non-null   float64
#  14  Minutes of Vigorous Work Daily            5433 non-null   float64
#  15  Moderate Work Activity                    26301 non-null  float64
#  16  Number of Days Moderate Work              10317 non-null  float64
#  17  Minutes of Moderate Work Daily            10264 non-null  float64
#  18  Walk or Bike Travel                       26301 non-null  float64
#  19  Number of Days Walk or Bike Weekly        4962 non-null   float64
#  20  Daily Minutes Walking or Biking           4927 non-null   float64
#  21  Vigorous Recreational Activity            26301 non-null  float64
#  22  Number of Days Vigorous Recreation        4068 non-null   float64
#  23  Minutes of Vigorous Recreation Daily      4063 non-null   float64
#  24  Moderate Recreational Activity            26301 non-null  float64
#  25  Number of Days Moderate Recreation        8913 non-null   float64
#  26  Minutes of Moderate Recreation Daily      8891 non-null   float64
#  27  Minutes of Sedentary Activity Daily       26243 non-null  float64
#  28  Bedtime Week/Workdays                     26893 non-null  object
#  29  Waketime Week/Workdays                    26893 non-null  object
#  30  Sleep Hours Week/Workdays                 26545 non-null  float64
#  31  Bedtime Weekends                          26893 non-null  object
#  32  Waketime Weekends                         26893 non-null  object
#  33  Sleep Hours Weekends                      26574 non-null  float64
#  34  Snoring Frequency Past Year               26893 non-null  float64
#  35  Frequency Snort/Stop Breathing Past Year  26893 non-null  float64
#  36  Told Doctor About Sleep Issues            26893 non-null  float64
#  37  Feeling Tired During Day Frequency        26893 non-null  float64
# dtypes: float64(34), object(4)
# memory usage: 9.6+ MB

# %% [markdown]
# ## Exporting Dataframe as CSV

# %%
Distilled_Data_Renamed.to_csv("Datasets/Filtered_Renamed_Data",
                  encoding="utf-8", index=False, header=True)
